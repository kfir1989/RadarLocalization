# %% [markdown]
# # Simulation A

# %% [markdown]
# ### Observations

# %%
# %load_ext autoreload
# %autoreload 2
from plotting import *
from database import SimulatedProcessedDatabase
from video import SimulationVideo
from tqdm import tqdm


name = "simulations/simulationA_orig_0"
data = SimulatedProcessedDatabase(name)

frames = [19]

fig, ax = plt.subplots(1,1,figsize=(20,15))
ax.axis('equal')

generateGraphSimulationMsr(data, frames, fig, ax)
plt.xticks(fontsize=20) 
plt.yticks(fontsize=20) 
plt.xlabel('x [m]', fontsize=32, labelpad=20.0)
plt.ylabel('y [m]', fontsize=32, labelpad=20.0)
ax.set_title(label=r"Observation with bias $t_0=5[m]$", y=1.03, fontsize=36)
ax.legend(prop={'size': 26})
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# self.dir_name images/simulations/simulationA_orig_0/database

# %% [markdown]
# ### Detection

# %%
# %load_ext autoreload
# %autoreload 2
from plotting import *
from database import SimulatedProcessedDatabase
from video import SimulationVideo
from tqdm import tqdm


name1 = "simulations/simulationA_1"
data1 = SimulatedProcessedDatabase(name1)
name2 = "simulations/simulationA_orig_1"
data2 = SimulatedProcessedDatabase(name2)

real_object = [{"c": [30,0,0.2], "xmin": -15, "xmax": 15, "fx": False}] #t0 offset

frames = [19]

fig, ax = plt.subplots(1,1,figsize=(20,15))
ax.axis('equal')

generateGraphSimulationComparison(data1, data2, frames, real_object, fig, ax)
plt.xticks(fontsize=20) 
plt.yticks(fontsize=20) 
plt.xlabel('x [m]', fontsize=32, labelpad=20.0)
plt.ylabel('y [m]', fontsize=32, labelpad=20.0)
ax.set_title(label=r"Detection with bias $t_0=5[m]$", y=1.03, fontsize=36)
ax.legend(prop={'size': 26})
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# self.dir_name images/simulations/simulationA_1/database
# self.dir_name images/simulations/simulationA_orig_1/database

# %% [markdown]
# # Simulation B

# %% [markdown]
# ### Observations

# %%
# %load_ext autoreload
# %autoreload 2
from plotting import *
from database import SimulatedProcessedDatabase
from video import SimulationVideo
from tqdm import tqdm


name = "simulations/simulationB_0"
data = SimulatedProcessedDatabase(name)

frames = [19]

fig, ax = plt.subplots(1,1,figsize=(20,15))
ax.axis('equal')

generateGraphSimulationMsr(data, frames, fig, ax)
plt.xticks(fontsize=20) 
plt.yticks(fontsize=20) 
plt.xlabel('x [m]', fontsize=32, labelpad=20.0)
plt.ylabel('y [m]', fontsize=32, labelpad=20.0)
ax.set_title(label=r"Observation with offset $x_0=5[m]$", y=1.03, fontsize=36)
ax.legend(prop={'size': 26})
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# self.dir_name images/simulations/simulationB_0/database

# %% [markdown]
# ### Detection

# %%
# %load_ext autoreload
# %autoreload 2
from plotting import *
from database import SimulatedProcessedDatabase
from video import SimulationVideo
from tqdm import tqdm


name1 = "simulations/simulationB_1"
data1 = SimulatedProcessedDatabase(name1)
name2 = "simulations/simulationB_orig_3"
data2 = SimulatedProcessedDatabase(name2)

real_object = [{"c": [35,-2,0.2], "xmin": -10, "xmax": 20, "fx": False}] #x0 offset

frames = [19]

fig, ax = plt.subplots(1,1,figsize=(20,15))
ax.axis('equal')

generateGraphSimulationComparison(data1, data2, frames, real_object, fig, ax)
plt.xticks(fontsize=20) 
plt.yticks(fontsize=20) 
plt.xlabel('x [m]', fontsize=32, labelpad=20.0)
plt.ylabel('y [m]', fontsize=32, labelpad=20.0)
ax.set_title(label=r"Detection with offset $x_0=5[m]$", y=1.03, fontsize=36)
ax.legend(prop={'size': 26})
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# self.dir_name images/simulations/simulationB_1/database
# self.dir_name images/simulations/simulationB_orig_3/database

# %% [markdown]
# # Simulation C

# %% [markdown]
# ### Observations

# %%
# %load_ext autoreload
# %autoreload 2
from plotting import *
from database import SimulatedProcessedDatabase
from video import SimulationVideo
from tqdm import tqdm


name = "simulations/simulationC_0"
data = SimulatedProcessedDatabase(name)

frames = [19]

fig, ax = plt.subplots(1,1,figsize=(20,15))
ax.axis('equal')

generateGraphSimulationMsr(data, frames, fig, ax, xlimits=[-5,30], ylimits=[-7, 25])
plt.xticks(fontsize=20) 
plt.yticks(fontsize=20) 
plt.xlabel('x [m]', fontsize=32, labelpad=20.0)
plt.ylabel('y [m]', fontsize=32, labelpad=20.0)
ax.set_title(label=r"Observation of the form $x = f(y)$", y=1.03, fontsize=36)
ax.legend(prop={'size': 26})
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# self.dir_name images/simulations/simulationC_0/database

# %% [markdown]
# ### Detection

# %%
# %load_ext autoreload
# %autoreload 2
from plotting import *
from database import SimulatedProcessedDatabase
from video import SimulationVideo
from tqdm import tqdm


name1 = "simulations/simulationC_1"
data1 = SimulatedProcessedDatabase(name1)
name2 = "simulations/simulationC_orig_3"
data2 = SimulatedProcessedDatabase(name2)

real_object = [{"c": [27.5,-5,0.3], "xmin": 5, "xmax": 16, "fx": True}] #f(y)

frames = [19]

fig, ax = plt.subplots(1,1,figsize=(20,15))
ax.axis('equal')

generateGraphSimulationComparison(data1, data2, frames, real_object, fig, ax, xlimits=[-5,30], ylimits=[-7, 25])
plt.xticks(fontsize=20) 
plt.yticks(fontsize=20) 
plt.xlabel('x [m]', fontsize=32, labelpad=20.0)
plt.ylabel('y [m]', fontsize=32, labelpad=20.0)
ax.set_title(label=r"Detection of object of the form $x = f(y)$", y=1.03, fontsize=36)
ax.legend(prop={'size': 26})
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# self.dir_name images/simulations/simulationC_1/database
# self.dir_name images/simulations/simulationC_orig_3/database

# %% [markdown]
# # Simulation D

# %%
# %load_ext autoreload
# %autoreload 2
from plotting import *
from database import SimulatedProcessedDatabase
from video import SimulationVideo
from tqdm import tqdm


name = "simulations/simulationD_1"
data = SimulatedProcessedDatabase(name)

frames = [19]

fig, ax = plt.subplots(1,2,figsize=(30,15),sharex=True,sharey=True)
ax[0].axis('equal')
ax[1].axis('equal')

generateGraphPerformance(data, frames, fig, ax, xlimits=[-50, 50], ylimits=[-7, 120])
ax[0].tick_params(axis="x", labelsize=25)
ax[0].tick_params(axis="y", labelsize=25)
ax[1].tick_params(axis="x", labelsize=25)
ax[1].tick_params(axis="y", labelsize=25)
fig.text(0.5, 0.04, 'x [m]', ha='center', fontsize=36)
fig.text(0.04, 0.5, 'y [m]', va='center', rotation='vertical', fontsize=36)
#ax[0].set_title(label=r"Simulation", y=1.03, fontsize=36)
ax[0].legend(loc='upper right',prop={'size': 26})
#ax[1].set_title(label=r"Simulation", y=1.03, fontsize=36)
ax[1].legend(prop={'size': 26})
plt.suptitle("Performance Evaluation", fontsize=40)
ax[0].text(0, -25, '(a)', ha='center', fontsize=36)
ax[1].text(0, -25, '(b)', ha='center', fontsize=36)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# self.dir_name images/simulations/simulationD_1/database
# Text(0,-25,'(b)')

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib.ticker import LinearLocator
import numpy as np

def computeDistForStaticTracks(polynom_rotated, boundary_rotated, curve=0, debug=False):

    dx = polynom_rotated[:,0].reshape(-1,1)-boundary_rotated[:,0].reshape(1,-1)
    dy = np.abs(polynom_rotated[:,1].reshape(-1,1)-boundary_rotated[:,1].reshape(1,-1))#+1

    #Force association on certain axis according to heading
    max_incline = 2
    min_incline = 0.5
    #derivative = (max(polynom_rotated[:, 0])-min(polynom_rotated[:, 0])) / (max(polynom_rotated[:, 1])-min(polynom_rotated[:, 1]))
    #straight_line_indication = curve < 0.1
    #if straight_line_indication and derivative > max_incline: #association should be on along track axis
    dxdy_norm = np.sqrt(10*dx**2 + 0.4*dy**2) #dx has higher priority
    #elif straight_line_indication and derivative < min_incline:
    #dxdy_norm = np.sqrt(0.4*dx**2 + 10*dy**2) #dy has higher priority
    #else:
    #dxdy_norm = np.sqrt(dx**2 + dy**2) #No one has any priority

    it = dxdy_norm.argmin(axis=1)

    dx_min = np.take_along_axis(dx, np.expand_dims(it, axis=-1), axis=1)
    dy_min = np.take_along_axis(dy, np.expand_dims(it, axis=-1), axis=1)
    dxdy_min = np.array([dx_min, dy_min])
    dxdy_min = np.squeeze(dxdy_min, -1) if dxdy_min.ndim == 3 else dxdy_min

    sigma_along_track = 0.5
    sigma_cross_track = 4
    P = np.array([[sigma_along_track, 0],[0, sigma_cross_track]])

    dist = np.sum(np.dot((dxdy_min.T)**2,np.linalg.inv(P)), axis=1)

    #take 20% highest
    n_elements = int(max(1, polynom_rotated.shape[0] / 5))
    #print(dist.shape, n_elements)
    top_ind = np.argpartition(dist, -n_elements)[-n_elements:]
    top20_dist = dist[top_ind]
    total_dist = np.mean(top20_dist)
    if debug:
        print("total_dist", total_dist, "polynom", polynom, "boundaryPoints", boundaryPoints, "dxdy_min", dxdy_min.T, "(dxdy_min.T)**2", (dxdy_min.T)**2, "top20_dist", top20_dist, "n_elements", n_elements, "top_ind", top_ind, "it", it)

    return total_dist


#fig = plt.subplots(figsize=(20,20))
fig = plt.figure(figsize=(20,10))

sim = False

if sim:
    ax = np.arange(-30,30,0.1)
    ay = np.zeros(ax.shape)
    a = np.array([ax, ay]).T

    X = np.arange(-10, 10, 0.1)
    Y = np.arange(-5, 5, 0.1)
    Z = np.zeros([Y.shape[0],X.shape[0]])
    for ix,x0 in enumerate(X):
        bx = np.arange(-30+x0,30+x0,0.1)
        for iy,y0 in enumerate(Y):
            by = np.ones(bx.shape) * y0
            b = np.array([bx, by]).T
            d = min(1e3, computeDistForStaticTracks(b,a))
            Z[iy, ix] = np.exp(-d**2/(2))
            #Z[iy, ix] = 1/d
            
    X, Y = np.meshgrid(X, Y)

ax = fig.add_subplot(1, 1, 1, projection='3d')
ax.axis('equal')


print("X,shape", X.shape, "Y.shape", Y.shape, "Z.shape", Z.shape)
# Plot the surface.
surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)

# Customize the z axis.
#ax.set_zlim(-1.01, 1.01)
#ax.zaxis.set_major_locator(LinearLocator(10))
# A StrMethodFormatter is used automatically
#ax.zaxis.set_major_formatter('{x:.02f}')

# Add a color bar which maps values to colors.
fig.colorbar(surf, shrink=0.5, aspect=5)
ax.set_xlabel('$\Delta_{lon}$ [m]', fontsize=24, labelpad=25)
ax.set_ylabel('$\Delta_{lat}$ [m]', fontsize=24, labelpad=25)
ax.set_zlabel('$w$', fontsize=24, labelpad=20)
ax.tick_params(labelsize=20)
#plt.zticks(fontsize=20) 
#plt.show()
#plt.title("Weighting  ", fontsize=40)
# Out:
# X,shape (100, 200) Y.shape (100, 200) Z.shape (100, 200)

# %%
# %load_ext autoreload
# %autoreload 2
from plotting import *
from database import SimulatedProcessedDatabase
from video import SimulationVideo
from tqdm import tqdm


fig, ax = plt.subplots(1,1,figsize=(15,10))
ax.axis('equal')

x = np.arange(-20,20,0.1)
y = 20 + 0.5*x

ax.plot(x,y,label='Road edge map',linewidth=5)

x = np.arange(-16,24,0.1)
y = 25 + 0.5*x
ax.plot(x,y,label='Road edge hypothesis',linewidth=5,linestyle='--')

plt.xticks(fontsize=20) 
plt.yticks(fontsize=20) 
ax.set_xlim([-20,20])
ax.set_ylim([-5,40])
plt.xlabel('x [m]', fontsize=22, labelpad=20.0)
plt.ylabel('y [m]', fontsize=22, labelpad=20.0)
#ax.set_title(label=r"Detection of object of the form $x = f(y)$", y=1.03, fontsize=36)

ax.annotate("", xy=(-14, 13), xytext=(-16, 17),
            arrowprops=dict(arrowstyle="<->"), fontsize=30)
ax.text(-15, 16, '$\Delta_{lat}$',
        fontsize = 25, rotation=30)

ax.annotate("", xy=(25, 35), xytext=(19.5, 32),
            arrowprops=dict(arrowstyle="<->"), fontsize=30)
ax.text(21.5, 32.5, '$\Delta_{lon}$',
        fontsize = 25, rotation=30)

x = np.arange(18.1,20,0.1)
y = 70 - 2*x
ax.plot(x, y, "g--")

x = np.arange(24,26.1,0.1)
y = 85 - 2*x
ax.plot(x, y, "g--")

ego1 = Rectangle((-30, 10), width=2, height=5, angle=-65,
                      facecolor='tab:blue', label='Ego true')

ego2 = Rectangle((-27, 16), width=2, height=5, angle=-65,
                      facecolor='tab:orange', label='Ego hypothesis')

ax.add_patch(ego1)
ax.add_patch(ego2)
ax.legend(prop={'size': 18})
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from nuscenes.nuscenes import NuScenes
directory = r"/home/kfir/workspace/nuScenes/v1.0-trainval"
nusc = NuScenes(version="v1.0-trainval", dataroot=directory, verbose=False)

# %%
# %load_ext autoreload
# %autoreload 2
from simulation import NuscenesSimulation

class DummyModel():
    def __init__(self):
        self.mm = True
        
scene = 690
dummy_model = DummyModel()
video_list={'video' : False, 'video_debug': False, 'video_pf': False, 'video_pf_xy': False, 'dynamic_tracker': False}
sim = NuscenesSimulation(nusc=nusc, model=dummy_model, scene_id=scene, Nmax=1200, video_list=video_list, save_processed=True)

data = NuscenesProcessedDatabase(scene_id=scene)
# Out:
# scene_id=690 scene_name=scene-0904 map_name=boston-seaport
# /home/kfir/workspace/RadarLocalization/dataset.py:376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   rot_imu = np.array([(m['utime'], m['q']) for m in self.imu])
# odom_speed [[1.53729795e+15 9.00000000e+00]
#  [1.53729795e+15 9.00000000e+00]
#  [1.53729795e+15 9.00000000e+00]
#  ...
#  [1.53729837e+15 2.80000000e+01]
#  [1.53729837e+15 2.90000000e+01]
#  [1.53729837e+15 2.90000000e+01]]
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# self.dir_name images/690/database
# ---------------------------------------------------------------------------
# ...

# %%
# %load_ext autoreload
# %autoreload 2
from database import NuscenesProcessedDatabase
from tqdm import tqdm
import matplotlib.pyplot as plt
data = NuscenesProcessedDatabase(scene_id=scene)
from plotting import PolynomsOnMapGraph
import matplotlib.patches as mpatches
import numpy as np
import pickle

def show_figure(fig):

    # create a dummy figure and use its
    # manager to display "fig"  
    dummy = plt.figure()
    new_manager = dummy.canvas.manager
    new_manager.canvas.figure = fig
    fig.set_canvas(new_manager.canvas)


nusc_map = sim.dataset.nusc_map
video_with_priors = True


from_file = False
save_file = False

if not from_file:
    fig, ax = plt.subplots(1,1,figsize=(20,15),sharex=True,sharey=True)

    plot = PolynomsOnMapGraph()
    for t in tqdm(range(0,1600)):
        img = sim.dataset.getSyncedImage(t)
        video_data, polynoms, points, dynamic_tracks, dynamic_clusters, mm_results, translation, debug_info = data.load(t)

        ax = plot.run(t, np.array(video_data['pos']), video_data["ego_path"], polynoms, nusc_map, fig, ax, xlimits=[300, 1000], ylimits=[300, 1000])
      
    if save_file:
        pickle.dump(fig, open('/home/kfir/workspace/RadarLocalization/figures/polynoms_on_map.fig.pickle', 'wb'))
else:
    fig = pickle.load(open('/home/kfir/workspace/RadarLocalization/figures/polynoms_on_map.fig.pickle', 'rb'))
    ax = figx.axes[0]
    
ax.tick_params(axis="x", labelsize=25)
ax.tick_params(axis="y", labelsize=25)
ax.tick_params(axis="x", labelsize=25)
ax.tick_params(axis="y", labelsize=25)
fig.text(0.5, 0.04, 'x [m]', ha='center', fontsize=36)
fig.text(0.14, 0.5, 'y [m]', va='center', rotation='vertical', fontsize=36)

magenta_patch = mpatches.Patch(color='magenta', label='road or curb edges')
ego_patch = mpatches.Patch(color='green', label='EGO')
ax.legend(handles=[magenta_patch, ego_patch], prop={'size': 26})
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# self.dir_name images/690/database
#   0%|          | 0/1600 [00:00<?, ?it/s]/home/kfir/.local/lib/python3.6/site-packages/nuscenes/map_expansion/map_api.py:1823: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   exteriors = [int_coords(poly.exterior.coords) for poly in polygons]
# /home/kfir/.local/lib/python3.6/site-packages/nuscenes/map_expansion/map_api.py:1824: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   interiors = [int_coords(pi.coords) for poly in polygons for pi in poly.interiors]
# ...

# %%
# %load_ext autoreload
# %autoreload 2
from simulation import NuscenesSimulation

class DummyModel():
    def __init__(self):
        self.mm = True
        
scene = 325
dummy_model = DummyModel()
video_list={'video' : False, 'video_debug': False, 'video_pf': False, 'video_pf_xy': False, 'dynamic_tracker': False}
sim = NuscenesSimulation(nusc=nusc, model=dummy_model, scene_id=scene, Nmax=1200, video_list=video_list, save_processed=True)

data = NuscenesProcessedDatabase(scene_id=scene)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# scene_id=325 scene_name=scene-0411 map_name=singapore-hollandvillage
# /home/kfir/workspace/RadarLocalization/dataset.py:376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   rot_imu = np.array([(m['utime'], m['q']) for m in self.imu])
# odom_speed [[1.53803387e+15 2.30000000e+01]
#  [1.53803387e+15 2.30000000e+01]
#  [1.53803387e+15 2.30000000e+01]
#  ...
#  [1.53898521e+15 1.70000000e+01]
#  [1.53898521e+15 1.70000000e+01]
#  [1.53898521e+15 1.70000000e+01]]
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# ...

# %%
# %load_ext autoreload
# %autoreload 2
from plotting import * 

fig, ax = plt.subplots(1,2,figsize=(30,10))
ax[0].axis('equal')
ax[1].axis('equal')

first = True
for t in tqdm(range(200,220)):
    img = sim.dataset.getSyncedImage(t+sim.dataset.first_idx)
    video_data, polynoms, points, dynamic_tracks, dynamic_clusters, mm_results, translation, debug_info = data.load(t)
    video_data["img"] = img
    
    if first:
        rotate_around = video_data["pos"][0:2].reshape([2,1])
    
    ax = generateGraphCurve(video_data, polynoms, mm_results, ax, xlimits=[1830, 1900], ylimits=[2570,2690], rotate=np.deg2rad(70), rotate_around=rotate_around)
    first = False
    
ax[0].tick_params(axis="x", labelsize=25)
ax[0].tick_params(axis="y", labelsize=25)
ax[1].tick_params(axis="x", labelsize=25)
ax[1].tick_params(axis="y", labelsize=25)
#fig.text(0.5, 0.04, 'x [m]', ha='center', fontsize=36)
#fig.text(0.14, 0.5, 'y [m]', va='center', rotation='vertical', fontsize=36)
ax[0].legend(loc='upper right',prop={'size': 26})
ax[1].legend(prop={'size': 26})
ax[1].set_xlabel('x [m]', fontsize=28, labelpad=25)
ax[1].set_ylabel('y [m]', fontsize=28, labelpad=25)
#plt.suptitle("Performance Evaluation", fontsize=40)
#ax[0].text(0, -25, '(a)', ha='center', fontsize=36)
#ax[1].text(0, -25, '(b)', ha='center', fontsize=36)
# Out:
#  15%|█▌        | 3/20 [00:00<00:00, 21.37it/s]
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# X.shape (2, 55)
# X.shape (2, 53)
# X.shape (2, 56)
#  30%|███       | 6/20 [00:00<00:00, 21.98it/s]
# X.shape (2, 57)
# X.shape (2, 70)
# X.shape (2, 58)
# X.shape (2, 57)
# X.shape (2, 52)
#  60%|██████    | 12/20 [00:00<00:00, 23.28it/s]
# X.shape (2, 47)
# X.shape (2, 52)
# X.shape (2, 56)
# X.shape (2, 56)
# X.shape (2, 52)
#  90%|█████████ | 18/20 [00:00<00:00, 23.74it/s]
# X.shape (2, 54)
# X.shape (2, 53)
# X.shape (2, 48)
# X.shape (2, 56)
# X.shape (2, 66)
# 100%|██████████| 20/20 [00:00<00:00, 23.41it/s]
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# X.shape (2, 62)
# X.shape (2, 58)
# Text(0, 0.5, 'y [m]')
